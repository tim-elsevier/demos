# %% [markdown]
# # Scenario 3.1 Resnet Search

# %%
#  import spark related modules
import pyspark
import socket
from pyspark.sql import SparkSession, SQLContext

 
# prevent error on rerunning if session is still alive
if 'sc' in globals():
    sc.stop()
    
# most configuration of the sparksession is done for you in the back
application_name = 'datastory 3 - resnet'

sparkSession = SparkSession.builder.appName(application_name)\
                           .config('spark.executor.memory', '4g')\
                           .config('spark.executor.instances', '5')\
                           .config('spark.sql.shuffle.partitions', '50')\
                           .config('spark.driver.memory', '4g')\
                           .config('spark.executor.cores', '3')\
                           .config('spark.driver.host', socket.gethostbyname(socket.gethostname()))\
                           .getOrCreate()

sc = sparkSession.sparkContext
sqlCtx = SQLContext(sc)

sc
# Out:
# <SparkContext master=k8s://https://kubernetes.default.svc.cluster.local:443 appName=datastory 3 - resnet>

# %%
from pyspark.sql.functions import broadcast
from pyspark.sql.functions import upper
from pyspark.sql.functions import lower
from pyspark.sql.functions import explode
from pyspark.sql.functions import col
from pyspark.sql.functions import split
from pyspark.sql.functions import countDistinct

# %%
from collections import defaultdict

# %% [markdown]
# ## 3.1

# %%
hdfs_path = "hdfs://demo-full-load-hdfs-namenode:8020"
data_path = hdfs_path + '/resnet/'

# %%
def cell_type_df():
    file = data_path+'elsevier-csv-resnet-celltype_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["CellType", "hasName", "hasProperty", "isMemberOf"])


def protein_df():
    file = data_path+'elsevier-csv-resnet-protein_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["Protein", "hasName", "hasProperty", "isMemberOf"])

def pathway_df():
    file = data_path+'elsevier-csv-resnet-pathway_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["Pathway", "hasName", "hasProperty", "isMemberOf"])

def group_df():
    file = data_path+'elsevier-csv-resnet-group_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["Group", "hasName", "hasProperty", "isMemberOf"])

def small_mol_df():
    file = data_path+'elsevier-csv-resnet-smallmol_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["SmallMol", "hasName", "hasProperty", "isMemberOf"])


def disease_df():
    file = data_path+'elsevier-csv-resnet-disease_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["Disease", "hasName", "hasProperty", "isMemberOf"])

def entity_property_df():
    file = data_path+'elsevier-csv-resnet-entityproperty_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["EntityProperty", "hasType", "hasPrimitiveValue"])


def property_types_df():
    file = data_path+'elsevier-csv-resnet-propertytype_deduplicated/*.csv'
    return sparkSession \
            .read \
            .option("header","true") \
            .csv(file) \
            .select(["PropertyType", "core_prefLabel"])

def description_df():
    types = property_types_df()
    
    description_uri = types.filter(types.core_prefLabel == "Description").toPandas().loc[0]['PropertyType']
    
    entity_properties = entity_property_df()
    return entity_properties \
            .filter(entity_properties.hasType == description_uri)\
            .where(entity_properties.hasPrimitiveValue.isNotNull())\
            .select(['EntityProperty', 'hasPrimitiveValue'])


def alias_df():
    types = property_types_df()
    
    alias_uri = types.filter(types.core_prefLabel == "Alias").toPandas().loc[0]['PropertyType']
    
    entity_properties = entity_property_df()
    return entity_properties \
            .filter(entity_properties.hasType == alias_uri)\
            .where(entity_properties.hasPrimitiveValue.isNotNull())\
            .select(['EntityProperty', 'hasPrimitiveValue'])

# %%
def attach_properties(spark_df):
    spark_df = spark_df.withColumn("hasProperty", explode(split(col("hasProperty"), "\\|\\|")).alias("hasProperty"))
    alias_items = alias_df()
    spark_df = spark_df.join(alias_items, alias_items.EntityProperty == spark_df.hasProperty, how='left')
    spark_df = spark_df.withColumnRenamed("hasPrimitiveValue", "hasAlias")
    spark_df = spark_df.drop('EntityProperty')

    description_items = description_df()
    spark_df = spark_df.join(description_items, description_items.EntityProperty == spark_df.hasProperty, how='left')
    spark_df = spark_df.withColumnRenamed("hasPrimitiveValue", "hasDescription")
    spark_df = spark_df.drop(*["EntityProperty", "hasProperty"])
    
    spark_df = spark_df.drop_duplicates()
    
    return spark_df

# %%
def get_pathways_by_uris(uris: list):
    pathways = attach_properties(pathway_df())
    
    uris_broadcast = sc.broadcast(uris)
    return pathways.filter(pathways.Pathway.isin(uris_broadcast.value))\
                .select(["Pathway", "hasName", "isMemberOf", "hasDescription", "hasAlias"])

def get_groups_by_uris(uris: list):
    groups = attach_properties(group_df())

    uris_broadcast = sc.broadcast(uris)
    return groups.filter(groups.Group.isin(uris_broadcast.value))\
                .select(["Group", "hasName", "isMemberOf", "hasDescription", "hasAlias"])



def resolve_memberships(memberships: str):
    if memberships is None:
        return None
    membership_items = memberships.split('||')
    
    memberships = defaultdict(list)
    
    for item in membership_items:
        membership_type = item.split('/')[-2]
        
        memberships[membership_type].append(item)
        
    return memberships


def explode_memberships(memberships: str, to_explode: list = ['pathway']):
    resolved_memberships = resolve_memberships(memberships)
    
    for key, item in resolved_memberships.items():
        if key == 'pathway':
            pathways_k = get_pathways_by_uris(item)
            
        elif key == 'group':
            groups_k = get_groups_by_uris(item)

# %%
import logging

pyspark_log = logging.getLogger('pyspark').setLevel(logging.ERROR)
py4j_logger = logging.getLogger("py4j").setLevel(logging.ERROR)


loggers = {}

def get_logger(logger_name):
        # create logger for prd_ci
        if loggers.get(logger_name):
            return loggers.get(logger_name)
        else:
            log = logging.getLogger(logger_name)
            log.setLevel(level=logging.INFO)

            # create formatter and add it to the handlers
            formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')


            # reate console handler for logger.
            ch = logging.StreamHandler()
            ch.setLevel(level=logging.INFO)
            ch.setFormatter(formatter)

            log.addHandler(ch)
            loggers[logger_name] = log
            return log

# %%
import pandas as pd


class ResNetSearch():
    def __init__(self, intensity: str = 'advanced'):
        """
        intensity can be 'advanced' or 'simple'
        """
        self.intensity = intensity
        
        self._validate_input()
        
        self.logger = get_logger("resnet.search")

        self.logger.info("ResNet search ready.")
        
        self.result_df_columns = ['Name', 'Entity', 'isMemberOf', 'Description', 'Alias']
        self.result_df = pd.DataFrame({}, columns=self.result_df_columns)
        
    def _validate_input(self):
        allowed_intensity = ["simple", "advanced"]
        
        if self.intensity not in allowed_intensity:
            raise ValueError("Unsupported search intentity, allowed: {}".format(allowed_intensity))

    def update_output(self):

        print("Found {} results...".format(len(self.result_df.index)), end='\r')
    
        
    def _update_results(self, new_results):
        if not new_results.empty:
            self.result_df = self.result_df.append(new_results[self.result_df_columns], ignore_index=True)
            self.update_output()
        
    def _format_results(self, df, entity_label: str):
        selection = df.rename(columns={
            "hasName": "Name", 
            "hasDescription": "Description",
            "hasAlias": "Alias"})
        selection["Entity"] = entity_label
        
        return selection
    
    def _reset_data(self):
        self.result_df = pd.DataFrame({}, columns=self.result_df_columns)
        
    def apply_simple_search(self, spark_df, entity_label, term):
        filtered_df = spark_df.where(lower(spark_df.hasName).contains(term))\
            .select([entity_label, 'isMemberOf', 'hasName', 'hasDescription', 'hasAlias'])
        
        return filtered_df
    
    def apply_advanced_search(self, spark_df, entity_label, term):
        filtered_df = spark_df.filter(
                lower(spark_df.hasName).contains(term) | \
                lower(spark_df.hasAlias).contains(term) | \
                lower(spark_df.hasDescription).contains(term)) \
            .select([entity_label, 'isMemberOf', 'hasName', 'hasDescription', 'hasAlias'])
        
        return filtered_df
        
    def apply_search_term(self, spark_df, entity_label, term):
        search_results = None
        if self.intensity == 'simple':
            search_results = self.apply_simple_search(spark_df, entity_label, term)
        elif self.intensity == 'advanced':
            search_results = self.apply_advanced_search(spark_df, entity_label, term)
        
        search_results_df = search_results.toPandas()
        formatted_results = self._format_results(df=search_results_df, entity_label=entity_label)
        self._update_results(formatted_results)
        
        return search_results_df
        
        
    def search_proteins(self, term):
        self.logger.info("Searching for proteins...")
        df = attach_properties(protein_df())

        proteins = self.apply_search_term(df, 'Protein', term)
        return proteins
    
    def search_small_mol(self, term):
        self.logger.info("Searching for small molecules...")
        df = attach_properties(small_mol_df())

        mols = self.apply_search_term(df, 'SmallMol', term)
        return mols
    
    def search_cells(self, term):
        self.logger.info("Searching for cells...")
        df = attach_properties(cell_type_df())

        cells = self.apply_search_term(df, 'CellType', term)
        return cells
    
    def search_diseases(self, term):
        self.logger.info("Searching for diseases...")
        df = attach_properties(disease_df())

        diseases = self.apply_search_term(df, 'Disease', term)
        return diseases
    
    def search_pathways(self, term):
        self.logger.info("Searching for pathways by text...")
        df = attach_properties(pathway_df())

        pathways = self.apply_search_term(df, 'Pathway', term)
        return pathways
        
    def get_groups_for_uris(self, group_uris: list):
        self.logger.info("Searching for groups...")

        groups_df = get_groups_by_uris(group_uris).toPandas()
        formatted_groups = self._format_results(df=groups_df, entity_label='Group')
        self._update_results(formatted_groups)
        
        return groups_df

    def get_pathways_for_uris(self, pathway_uris: list):
        self.logger.info("Searching for pathways...")

        pathways_df = get_pathways_by_uris(pathway_uris).toPandas()
        formatted_pathways = self._format_results(df=pathways_df, entity_label='Pathway')
        self._update_results(formatted_pathways)
        
        return pathways_df
    
    def explode_memberships(self, entities: pd.DataFrame):
        self.logger.info("Searching for memberships...")

        membership_series = entities['isMemberOf'].apply(lambda x: resolve_memberships(x))
        
        all_pathways = []
        all_groups = []
        
        for membership_dict in membership_series:
            if membership_dict is not None:
                all_pathways = all_pathways + membership_dict['pathway']
                all_pathways = all_pathways + membership_dict['group']
            
        all_pathways = list(set(all_pathways))
        all_groups = list(set(all_groups))
        
        return all_pathways, all_groups
            
        
    def get_descriptions(self):
        """Unused..."""
        self.logger.info("Fetching descriptions...")
        
        sdf = sqlCtx.createDataFrame(self.result_df.copy())
        
        sdf = sdf.withColumn("hasProperty", explode(split(col("hasProperty"), "\\|\\|")).alias("hasProperty"))
        
        all_descriptions = description_df()

        sdf = sdf.join(all_descriptions, sdf.hasProperty == all_descriptions.EntityProperty, how='left')
        
        df = sdf.toPandas()
        
        self._reset_data()

        self.result_df = df
        
        self.result_df = self.result_df.rename(columns={"hasPrimitiveValue": "Description"})
        
        
    def search(self, term: str, limit=10) -> pd.DataFrame:
        self._reset_data()
        
        term = term.lower()
        
        # Protein
        proteins_df = self.search_proteins(term)
        
        smallmol_df = self.search_small_mol(term)
        
        cells_df = self.search_cells(term)
        
        diseases_df = self.search_diseases(term)
        
        pathways_text_df = self.search_pathways(term)
        
        entities_df = proteins_df.append(smallmol_df.append(cells_df.append(diseases_df)))
        
        all_pathways, all_groups = self.explode_memberships(entities_df)

        pathways = self.get_pathways_for_uris(all_pathways)
        groups = self.get_groups_for_uris(all_groups)
        
        self.logger.info("Formatting and deduplicating...")
        
        deduped = self.result_df[['Name', 'Description', 'Entity', 'Alias']]\
                    .sort_values(by=['Entity','Name', 'Description']) \
                    .drop_duplicates(subset=['Name', 'Entity'], keep='first')\
                    .reset_index(drop=True)
        
        self.logger.info("Showing {} results...".format(len(deduped)))
        return deduped

# %%
search_application = ResNetSearch(intensity="advanced")
# Out:
# 2020-09-09 12:34:26,763 - resnet.search - INFO - ResNet search ready.

# %%
search_results = search_application.search("hela")
search_results
# Out:
# 2020-09-09 12:34:26,771 - resnet.search - INFO - Searching for proteins...
# 2020-09-09 12:34:51,245 - resnet.search - INFO - Searching for small molecules...
# Found 16 results...
# 2020-09-09 12:35:05,003 - resnet.search - INFO - Searching for cells...
# Found 121 results...
# 2020-09-09 12:35:12,997 - resnet.search - INFO - Searching for diseases...
# Found 148 results...
# 2020-09-09 12:35:21,194 - resnet.search - INFO - Searching for pathways by text...
# Found 154 results...
# 2020-09-09 12:35:28,005 - resnet.search - INFO - Searching for memberships...
# 2020-09-09 12:35:28,007 - resnet.search - INFO - Searching for pathways...
# Found 158 results...
# 2020-09-09 12:35:34,285 - resnet.search - INFO - Searching for groups...
# Found 176 results...
# 2020-09-09 12:35:36,583 - resnet.search - INFO - Formatting and deduplicating...
# 2020-09-09 12:35:36,588 - resnet.search - INFO - Showing 122 results...
#                            Name                        Description    Entity  \
# 0                        H1HeLa  uterine cervical cancer cell line  CellType
# 1                          HeLa  uterine cervical cancer cell line  CellType
# 2                      HeLa 229  uterine cervical cancer cell line  CellType
# 3                       HeLa P4  uterine cervical cancer cell line  CellType
# 4                        HeLa S  uterine cervical cancer cell line  CellType
# ..                          ...                                ...       ...
# 117                vat yellow 4                               None  SmallMol
# 118                        zinc                               None  SmallMol
# 119        zinc acetylacetonate                               None  SmallMol
# 120  zinc chelator calcium EDTA                               None  SmallMol
# 121         zinc protoporphyrin                               None  SmallMol
#
#                                                  Alias
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 117  C.I. Vat Yellow 4||CCRIS 176||Tinon Golden Yel...
# 118  zincum||Zinc (dust or fume)||Granular zinc||me...
# 119  Bis(pentanedionato)zinc||Zinc 2 4-pentanediona...
# 120                                               None
# 121  ZnPP||protoporphyrin zinc||Zn-P||ZnPP9||ZINC P...
#
# [122 rows x 4 columns]

# %%
pd.set_option('display.max_rows', 500)

display(search_results)

pd.reset_option('display.max_rows')
# Out:
#                                                   Name  \
# 0                                               H1HeLa
# 1                                                 HeLa
# 2                                             HeLa 229
# 3                                              HeLa P4
# 4                                               HeLa S
# 5                                              HeLa S3
# 6                                             HeLa-APL
# 7                                             HeLa-luc
# 8                                             HeLaRC32
# 9                        erythropoietic protoporphyria
# 10                                      monosomy 22q13
# 11                                  precocious puberty
# 12                                         thelaziosis
# 13                                            xanthoma
# 14   2_High levels of hepcidin block iron absorptio...
# 15           FXN Role in Friedreich Ataxia Progression
# 16          Hematopoietic Cell Lineage: B-cell (mouse)
# 17                            Phelan-McDermid Syndrome
# 18       Proteins Involved in Phelan-McDermid Syndrome
# 19                 T-Cell Acute Lymphoblastic Leukemia
# 20   T-Cell Genetic Rearrangements in Acute Lymphob...
# 21                                              CYB561
# 22                                              CYBRD1
# 23                                                FECH
# 24                                              FECHP1
# 25                                              FLVCR2
# 26                                               FRRS1
# 27                                              FRRS1L
# 28                                               LYPD1
# 29                                                NAV2
# 30                                                 ST3
# 31                                                 ST5
# 32                                               TCF12
# 33                                 1 10-phenanthroline
# 34     1-[ethan-1-ol]-2-methyl-3- hydroxypyridin-4-one
# 35               1-ethyl-2-methyl-3-hydroxypyrid-4-one
# 36                      8-hydroxyquinoline derivatives
# 37                                            BAPTA-AM
# 38                                            Brown SK
# 39                                           CaNa2EDTA
# 40                                    Cibanone Olive B
# 41               Cobalt N-fluoren-2-ylacetohydroxamate
# 42                                              DH-40J
# 43                                               E 130
# 44                                         Fe(II)-EDTA
# 45                                         Fe(III)EDTA
# 46                                           Ferrochel
# 47                                     Leucosol Blue G
# 48                                        N2S4 chelate
# 49                                           PHELAZINE
# 50                                     Pigment Red 168
# 51                                     Reactive Blue 4
# 52                                  TSKgel Heparin-5PW
# 53                                              Tc-99m
# 54                                         Tc-99m DTPA
# 55                                        Vat Orange 1
# 56                                          Vat blue 6
# 57                                         Vat green 2
# 58                                         Yb-169 DTPA
# 59                       [Eu-DTTA chelate]-EGF (human)
# 60                                        aphelandrine
# 61                                        baciphelacin
# 62                             calcium chelating agent
# 63                           calcium-specific chelator
# 64                                       chelated iron
# 65                                  chelated protohaem
# 66                                     chelating agent
# 67                                 chromium methionine
# 68                                      clarithromycin
# 69                                         cobalt-EDTA
# 70                                    cobalt-bleomycin
# 71                                    copper bleomycin
# 72                                    copper gluconate
# 73                                      copper-citrate
# 74                                             coronin
# 75                                         deferiprone
# 76                                        deferoxamine
# 77                                           deltaline
# 78                                             diamsar
# 79                                       disodium EDTA
# 80                                         epinephrine
# 81                                        erythromycin
# 82                                         ferric DTPA
# 83                              ferric choline citrate
# 84                            ferric nitrilotriacetate
# 85                                        ferrioxamine
# 86                                  gadolinium chelate
# 87                           gadopentetate dimeglumine
# 88                                           ibuprofen
# 89                                  iminodiacetic acid
# 90                                            indicine
# 91                                iron chelating agent
# 92                                             lactose
# 93                                            levodopa
# 94                                  magnesium pemoline
# 95                              manganese EDTA complex
# 96                                           melphalan
# 97                                       metal chelate
# 98                                     metal chelators
# 99                                         neocuproine
# 100                                     nickel chelate
# 101                         o-hydroxyphenylacetic acid
# 102                                            oxalate
# 103                                       oxine-copper
# 104                                       parbendazole
# 105                                     permanent pink
# 106                                      phytochelatin
# 107                                        polaprezinc
# 108                                         pyrithione
# 109                                              quin2
# 110                                        sar chelate
# 111                                      tin compounds
# 112                                 trachelanthamidine
# 113                                   trachelanthamine
# 114                           trachelanthamine-N-oxide
# 115                                          trientine
# 116                                        vat green 1
# 117                                       vat yellow 4
# 118                                               zinc
# 119                               zinc acetylacetonate
# 120                         zinc chelator calcium EDTA
# 121                                zinc protoporphyrin
#
#                                            Description    Entity  \
# 0                    uterine cervical cancer cell line  CellType
# 1                    uterine cervical cancer cell line  CellType
# 2                    uterine cervical cancer cell line  CellType
# 3                    uterine cervical cancer cell line  CellType
# 4                    uterine cervical cancer cell line  CellType
# 5                    uterine cervical cancer cell line  CellType
# 6                    uterine cervical cancer cell line  CellType
# 7    luciferase-transfected cell line  luciferase-t...  CellType
# 8                    uterine cervical cancer cell line  CellType
# 9                                                 None   Disease
# 10                                                None   Disease
# 11                                                None   Disease
# 12                                                None   Disease
# 13                                                None   Disease
# 14   published in: Disease Pathways: An Atlas of Hu...   Pathway
# 15   Pathway is built manually using published stud...   Pathway
# 16   Hematopoietic stem cells (HSCs) are progenitor...   Pathway
# 17   The role of mutations in the SHANK3 gene in th...   Pathway
# 18   Pathway is built using manually-curated ResNet...   Pathway
# 19   T-cell acute lymphoblastic leukemia (T-ALL) re...   Pathway
# 20   Several recurrent genetic alterations have bee...   Pathway
# 21                                                None   Protein
# 22                                                None   Protein
# 23                                      ferrochelatase   Protein
# 24                         ferrochelatase pseudogene 1   Protein
# 25                                                None   Protein
# 26                          ferric chelate reductase 1   Protein
# 27                     ferric chelate reductase 1 like   Protein
# 28                                                None   Protein
# 29                                                None   Protein
# 30                                                None   Protein
# 31                                                None   Protein
# 32                                                None   Protein
# 33                                                None  SmallMol
# 34                                                None  SmallMol
# 35                                                None  SmallMol
# 36                                                None  SmallMol
# 37                                                None  SmallMol
# 38                                                None  SmallMol
# 39                                                None  SmallMol
# 40                                                None  SmallMol
# 41                                                None  SmallMol
# 42                                                None  SmallMol
# 43                                                None  SmallMol
# 44                                                None  SmallMol
# 45                                                None  SmallMol
# 46                                                None  SmallMol
# 47                                                None  SmallMol
# 48                                                None  SmallMol
# 49                                                None  SmallMol
# 50                                                None  SmallMol
# 51                                                None  SmallMol
# 52                                                None  SmallMol
# 53                                                None  SmallMol
# 54                                                None  SmallMol
# 55                                                None  SmallMol
# 56                                                None  SmallMol
# 57                                                None  SmallMol
# 58                                                None  SmallMol
# 59                                                None  SmallMol
# 60                                                None  SmallMol
# 61                                                None  SmallMol
# 62                                                None  SmallMol
# 63                                                None  SmallMol
# 64                                                None  SmallMol
# 65                                                None  SmallMol
# 66                                                None  SmallMol
# 67                                                None  SmallMol
# 68                                                None  SmallMol
# 69                                                None  SmallMol
# 70                                                None  SmallMol
# 71                                                None  SmallMol
# 72                                                None  SmallMol
# 73                                                None  SmallMol
# 74                                                None  SmallMol
# 75                                                None  SmallMol
# 76                                                None  SmallMol
# 77                                                None  SmallMol
# 78                                                None  SmallMol
# 79                                                None  SmallMol
# 80                                                None  SmallMol
# 81                                                None  SmallMol
# 82                                                None  SmallMol
# 83                                                None  SmallMol
# 84                                                None  SmallMol
# 85                                                None  SmallMol
# 86                                                None  SmallMol
# 87                                                None  SmallMol
# 88                                                None  SmallMol
# 89                                                None  SmallMol
# 90                                                None  SmallMol
# 91                                                None  SmallMol
# 92                                                None  SmallMol
# 93                                                None  SmallMol
# 94                                                None  SmallMol
# 95                                                None  SmallMol
# 96                                                None  SmallMol
# 97                                                None  SmallMol
# 98                                                None  SmallMol
# 99                                                None  SmallMol
# 100                                               None  SmallMol
# 101                                               None  SmallMol
# 102                                               None  SmallMol
# 103                                               None  SmallMol
# 104                                               None  SmallMol
# 105                                               None  SmallMol
# 106                                               None  SmallMol
# 107                                               None  SmallMol
# 108                                               None  SmallMol
# 109                                               None  SmallMol
# 110                                               None  SmallMol
# 111                                               None  SmallMol
# 112                                               None  SmallMol
# 113                                               None  SmallMol
# 114                                               None  SmallMol
# 115                                               None  SmallMol
# 116                                               None  SmallMol
# 117                                               None  SmallMol
# 118                                               None  SmallMol
# 119                                               None  SmallMol
# 120                                               None  SmallMol
# 121                                               None  SmallMol
#
#                                                  Alias
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9    protoporphyrinuria||deficiency of ferrochelata...
# 10   22q13.3 deletion syndromes||Phelan-McDermid sy...
# 11   True Precocious Puberty||Accelerated Sexual Ma...
# 12                                                None
# 13   Xanthomata||xanthomatous skin lesions||skin xa...
# 14                                                None
# 15                                                None
# 16                                                None
# 17                                                None
# 18                                                None
# 19                                                None
# 20                                                None
# 21   cytochrome b-561||OTTMUSP00000003024||ORTHYP2|...
# 22   OTTHUMP00000205026||CYB561A2||Cybrd1||cytochro...
# 23                                                None
# 24                                                None
# 25   FLVCRL14q||EPV||transporter||SLC49A2||PVHH||cD...
# 26                                                None
# 27                                                None
# 28   ly-6/neurotoxin-like protein 2||lypdc1||RIKEN ...
# 29   retinoic acid inducible gene in neuroblastoma ...
# 30   suppressor of tumorigenicity III||suppression ...
# 31   2010004M01Rik||heLa tumor suppression 1||HTS I...
# 32   ALF1||helix-loop-helix transcription factors 4...
# 33   1 10-Phenanthroline monohydrate||1 10-Phenanth...
# 34   BRN 1454566||1-(Ethan-1-ol)-2-methyl-3-hydroxy...
# 35   1-EMHP-one||1-ethyl-3-hydroxy-2-methyl-4-pyrid...
# 36   cryptonal||sulphanoline||8 quinolinol derivati...
# 37   bis(2-aminophenoxy)ethane-N N N' N'-tetra-acet...
# 38   Chemithrene Brown BR||Mikethrene Brown GR||Ind...
# 39   Edetato sodico calcico||12264-18-5||EINECS 200...
# 40   Calcoloid Olive Green BN||Zelen kypova 3||Aman...
# 41   Cobalt N-fluoren-2-ylacetohydroxamate||N-Hydro...
# 42          DH-40J||zinc chelated pentosan polysulfate
# 43   Helanthrene Blue RS||Monolite Fast Blue SRS||P...
# 44   923-71-7||Fe(II)-EDTA  sodium-hydrogen salt||D...
# 45   Natrium-eisen(III)-edetat||Ferric versenate||1...
# 46   ferrous bisglycinate||ferrochel||iron glycinat...
# 47   Cibanone Blue GCD||NSC 299138||Indanthren Blue...
# 48                                                None
# 49                                                None
# 50   Tyrian Brilliant Orange I-RK||Helio Fast Scarl...
# 51   "1-amino-4-((3-((4 6-dichloro-1 3 5-triazin-2-...
# 52   TSK-Gel Heparin 5PW||gel chelate-5PW||TSKgel h...
# 53   Tc 99||Tc-99 m||colloid technetium||technetium...
# 54   Technetium tc 99m pentetate||technetium  penta...
# 55   EINECS 215-363-2||C.I. Vat Orange 1||Threne go...
# 56   D&C Blue 9||Palanthrene Blue BC||Carbanthrene ...
# 57   Vat Brilliant Green ZH||Helanthrene Green 2G||...
# 58   ytterbium Yb-169 DTPA||ytterbium DTPA  dihydri...
# 59                                                None
# 60                            Aphelandrine||69721-57-9
# 61   Baciphelacin||Antibiotic B-17||5-amino-2 5 6 7...
# 62                                                None
# 63   4-Methyl-1 2-bis(2 2'-bis(carboxymethyl)aminop...
# 64          iron chelates||iron chelate||chelated iron
# 65   Protohemin mono-3-(imidazole-1-yl)propylamide ...
# 66                                                None
# 67   Cr methionine complex||Availa-Cr||chromium met...
# 68   klaricid adult||clarithromycin extended releas...
# 69   (ethylenedinitrilo)tetra-acetic acid cobalt sa...
# 70   cobalt bleomycin||bleomycin cobalt||bleomycin ...
# 71   bleomycin copper complex||Copper bleomycin||Bl...
# 72   Copper(2+) D-gluconate  (1:2)||bis(D-gluconato...
# 73   Copper citrate (x-Cu(x))||1 2 3-Propanetricarb...
# 74   Khelline||vismagen||Khellanals||Khelangin||5 8...
# 75   3-Hydroxy-1 2-dimethyl-4(1H)-pyridone||Ferripr...
# 76   EINECS 200-738-5||propionohydroxamic acid  n-[...
# 77   deltaline||Eldelin||BRN 0067504||Delphelatine|...
# 78   3 6 10 13 16 19-Hexaazabicyclo(6.6.6)eicosane-...
# 79   Hamp-ene Na2||EDTA Na2||anhydrous disodium EDT...
# 80   Epinephran||adrin||Stryptirenal||metanephrin||...
# 81   e-glades||Derimer||Aknederm Ery Gel||N-Methyle...
# 82   iron diethylenetriamine pentaacetic acid||Ferr...
# 83   Iron choline citrate||Ferrocolinato||ferrichol...
# 84   FeNTA||HSDB 1306||16448-54-7||Fe(3+) NTA||2-(b...
# 85   Fe(3+) chelator desferrioxamine||(N-(5-(3-((5-...
# 86                                                None
# 87   magnograf||magnevist enteral||meglumine gadope...
# 88   advil alpha-methyl-4-(2-methylpropyl)benzeneac...
# 89   2 2'-Iminodiacetate||Diglycocoll||Diglycollama...
# 90   Heliotridine trachelanthate HCl||O-demethyl-He...
# 91                                                None
# 92   14641-93-1||lactose||63-42-3||Pharmatose 21||[...
# 93   Larodopa R||Dihydroxy-L-phenylalanine||dextrol...
# 94   Pemoline magnesium||4(5H)-Oxazolidinone  2-ami...
# 95   NSC 7345||manganese EDTA complex||(ethylenedin...
# 96   L-Phenylalanine mustard HCl||Alanine nitrogen ...
# 97                                                None
# 98   metal ion chelator||heavy metal ion chelators|...
# 99   neocuproine HCl||3 6-dimethyl-4 5-phenanthroli...
# 100                     nickel complex||nickel chelate
# 101  (2-hydroxyphenyl)acetic acid||EINECS 210-393-2...
# 102  CCRIS 1454||Ethanedioic acid-d2||Aquisal||Etha...
# 103  8-Quinolinol  copper salt||Timtex AQS||Bis(8-o...
# 104  2-(14)C-labeled cpd di-HCl Parbendazole||Parbe...
# 105  Fenanthren Brilliant Pink R||Nyanthrene Brilli...
# 106                                               None
# 107  Promac||beta alanylhistidine zinc||carnosine z...
# 108  5412-36-2||AI3-60234||AL02725||1-oxide sodium ...
# 109  2-((2-(bis(carboxymethyl)amino)-5-methylphenox...
# 110                                               None
# 111  stannous salt||tin derivative||tin salts||tin ...
# 112                                               None
# 113  14140-18-2||BUTANOIC ACID  2 3-DIHYDROXY-2-(1-...
# 114  510-19-0||Trachelanthamine oxide||2 3-dihydrox...
# 115  N N'-bis(2-aminoethyl)ethane-1 2-diamine||3826...
# 116  Brilliant Green S||Pernithrene Brilliant Green...
# 117  C.I. Vat Yellow 4||CCRIS 176||Tinon Golden Yel...
# 118  zincum||Zinc (dust or fume)||Granular zinc||me...
# 119  Bis(pentanedionato)zinc||Zinc 2 4-pentanediona...
# 120                                               None
# 121  ZnPP||protoporphyrin zinc||Zn-P||ZnPP9||ZINC P...
